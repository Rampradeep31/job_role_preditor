# %%
import pandas as pd
import os

# 1. LOAD DATA
csv_path = "../dataset/education_career_success.csv"
df = pd.read_csv(csv_path)

# 2. VIEW RAW STATS
print("--- Raw Data Stats ---")
print(df.info())
print("\n--- Missing Values ---")
print(df.isnull().sum())

# 3. OPTIONAL: VIEW THE PREPROCESSED FILE
# (Run this ONLY after you have run ML_Model.ipynb)
processed_path = "../dataset/preprocessed_data.csv"
if os.path.exists(processed_path):
    print("\n✅ Found Preprocessed Data:")
    df_proc = pd.read_csv(processed_path)
    print(df_proc.head())
else:
    print("\nℹ️ Preprocessed data not found yet. Run ML_Model.ipynb first.")
# Out:
# --- Raw Data Stats ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3450 entries, 0 to 3449
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             400 non-null    object
#  1   Age                    400 non-null    float64
#  2   Gender                 400 non-null    object
#  3   High_School_GPA        400 non-null    float64
#  4   SAT_Score              400 non-null    float64
#  5   University_GPA         3450 non-null   float64
#  6   Field_of_Study         3450 non-null   object
#  7   Internships_Completed  3450 non-null   int64
#  8   Projects_Completed     400 non-null    float64
#  9   Certifications         3146 non-null   object
#  10  Soft_Skills_Score      400 non-null    float64
#  11  Networking_Score       400 non-null    float64
#  12  Job_Offers             400 non-null    float64
#  13  Starting_Salary        400 non-null    float64
# ...
